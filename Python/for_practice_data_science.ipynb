# %%
import matplotlib.pyplot as plt, numpy as np 

# %matplotlib inline

# plt.show()               ---> Draws the Plot in VSCode

x = np.linspace(0, 5, 11)
y = x ** 2

# 2 ways of Creating Matplotlibb Plots

# 1. Functional Method            ----> This is simple

plt.plot(x,y)
